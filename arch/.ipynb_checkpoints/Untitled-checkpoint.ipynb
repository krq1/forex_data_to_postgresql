# %%
#

# %%
#10

# %%
clear

# %%
1/2
# Out:
# 0.5

# %%
5/2
# Out:
# 2.5

# %%
5%2
# Out:
# 1

# %%
2+3 * 5+6
# Out:
# 23

# %%
(2+3) * (5+6)
# Out:
# 55

# %%
name_var = 2

# %%
name_var2 = 3

# %%
name_var + name_var2
# Out:
# 5

# %%
z = name_var + name_var2

# %%
z
# Out:
# 5

# %%
'single'
# Out:
# 'single'

# %%
"doubel"
# Out:
# 'doubel'

# %%
"Don't"
# Out:
# "Don't"

# %%
x = hello
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-26-f5c0b3a4181c> in <module>()
# ----> 1 x = hello
#
# NameError: name 'hello' is not defined

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
name = 'Marcin Stopa'

# %%
print(name)
# Out:
# Marcin Stopa

# %%
print('My name is {}'.format(name))
# Out:
# My name is Marcin Stopa

# %%
number = 12

# %%
print("Hi my name is {} and my number is {}".format(name,number))
# Out:
# Hi my name is Marcin Stopa and my number is 12

# %%
#LIST
[1,2,3]
# Out:
# [1, 2, 3]

# %%
#multiple datatype
my list = ['hi',1,3]
# Out:
#   File "<ipython-input-38-2f1901991088>", line 2
#     my list = ['hi',1,3]
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# my_list = [1,2,3]

# %%
my_list.append(4)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-39-8ac09a880ea3> in <module>()
# ----> 1 my_list.append(4)
#
# NameError: name 'my_list' is not defined

# %%
my_list
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-40-b9f395265c26> in <module>()
# ----> 1 my_list
#
# NameError: name 'my_list' is not defined

# %%
my_list=[1,2,3]

# %%
my_list.append(4)

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
my_list = ['a','b', 'c']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[0:2]
# Out:
# ['a', 'b']

# %%
nested = [1,2,['a','b']]

# %%
nested[2]
# Out:
# ['a', 'b']

# %%
nested[2][0]
# Out:
# 'a'

# %%
d = {'key':10, 'key2':'seconditem'}

# %%
d['key2']
# Out:
# 'seconditem'

# %%
t = (1,2,3)

# %%
my_list[1] = "NEW"

# %%
print(1)
# Out:
# 1

# %%
t(1) = "NEW"
# Out:
#   File "<ipython-input-61-d5d8cef42154>", line 1
#     t(1) = "NEW"
#                 ^
# SyntaxError: can't assign to function call

# %%
{21,222,2,2,2,33}
# Out:
# {2, 21, 33, 222}

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
1 != 3
# Out:
# True

# %%
# logic operators

# %%
(1==2) and (1==1)
# Out:
# False

# %%
(1==2) or (1==1)
# Out:
# True

# %%
(1==1) and not (1==2)
# Out:
# True

# %%
if 1==2:
    print('hello')
elif 2==2:
    print('two')
else:
    print('elo not true')
# Out:
# two
